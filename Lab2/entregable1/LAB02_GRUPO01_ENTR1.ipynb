# %% [markdown]
# # Laboratorio 2 - Reglas de Asociación y Patrones Secuenciales
#
# ## Grupo 1 - Paula Hípola Gómez, José Ignacio Navas Sanz y Belén Ortega Pérez
#
# ## Entregable 1 - Reglas de Asociación
#
# ### 1.1 (1 punto) Estudia brevemente el dataset (número de usuarios, número de atributos, categorías más frecuentes para cada atributo/columna, etc.) y realiza el preprocesamiento para generar el dataset necesario para aplicar el algoritmo Apriori a este conjunto de datos.

# %%
# %config IPCompleter.greedy=True
# %reset
#Importamos las librerías necesarias
#Numpy
import numpy as np 
#Pandas
import pandas as pd
#Scikit-Learn
import sklearn as sk
#Matplotlib
import matplotlib.pyplot as plt
#Importamos la libreria mlxtend
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
# Out:
# Once deleted, variables cannot be recovered. Proceed (y/[n])? Y

# %% [markdown]
# ### Cargamos los datos y los visualizamos

# %%
#Importamos el CSV
dataset = pd.read_csv('radio.csv')

#Mostramos los datos
dataset
# Out:
#          user                   artist sex  country
# 0           1    red hot chili peppers   f  Germany
# 1           1  the black dahlia murder   f  Germany
# 2           1                goldfrapp   f  Germany
# 3           1         dropkick murphys   f  Germany
# 4           1                 le tigre   f  Germany
# ...       ...                      ...  ..      ...
# 289950  19718                bob dylan   f   Canada
# 289951  19718                   pixies   f   Canada
# 289952  19718                the clash   f   Canada
# 289953  19718     a tribe called quest   f   Canada
# 289954  19718                radiohead   f   Canada
#
# [289955 rows x 4 columns]

# %%
print('La dimensión del dataset es:',dataset.shape)
# Out:
# La dimensión del dataset es: (289955, 4)

# %% [markdown]
# Tenemos 289955 instancias y 4 atributos, para cada una de nuestras instancias. Analizando más profundamente el dataset, está compuesto con las interacciones de cada usuario que ha escuchado al menos a un artista. Vamos a ver cuantos valores tenemos actualmente en cuanto a usuarios, artistas y demás atributos y luego procederemos a identificar en el dataset valores duplicados y nulos que dificultan la comprensión de los datos y procederemos a su eliminación.

# %% [markdown]
# ### Analizando los datos

# %%
#Valores desconocidos
desconocidos = dataset.loc[dataset['artist'] == '[unknown]']
print('Hay ', desconocidos.shape[0], 'valores desconocidos.');
# Out:
# Hay  553 valores desconocidos.

# %%
numUsuarios = dataset.groupby('user').count().shape[0]
print('Hay',numUsuarios,'usuarios.')
numArtistas = dataset.groupby('artist').count().shape[0]
print('Hay',numArtistas,'artistas.')
numSexos = dataset.groupby('sex').count().shape[0]
print('Hay',numSexos,'géneros.')
numPaises = dataset.groupby('country').count().shape[0]
print('Hay',numPaises,'países.')
# Out:
# Hay 15000 usuarios.
# Hay 1004 artistas.
# Hay 2 géneros.
# Hay 159 países.

# %%
dataset['user'].describe()
# Out:
# count    289955.000000
# mean       9852.460447
# std        5692.355041
# min           1.000000
# 25%        4935.000000
# 50%        9838.000000
# 75%       14769.000000
# max       19718.000000
# Name: user, dtype: float64

# %% [markdown]
# Vemos que el valor máximo para usuarios es 19718 pero realmente hay 15000 usuarios. Esto se debe a que en la tabla tenemos las transacciones de aquellos que han escuchado al menos una canción pero guarda su ID de registro, es decir, cuando un Usuario se registra se le asigna un ID, por ejemplo el 1, pero si ese usuario no escucha ninguna canción, no estará en nuestra base de datos. En cambio si el siguiente usuario con ID 4 si escucha una canción si le tendremos en nuestro registro, de ahí que el valor máximo de usuarios sea 19718 pero realmente solo tenemos 15000.

# %%
dataset['artist'].describe()
# Out:
# count        289955
# unique         1004
# top       radiohead
# freq           2704
# Name: artist, dtype: object

# %% [markdown]
# Respecto a los artistas, antes hemos obtenido que había 1004 y efectivamente es lo que obtenemos cuando llamamos a la funcón 'describe'. Observamos que el artista más escuchado es radiohead, podremos analizar a este artista con respecto a los demás si tenemos algún interés especial en él.

# %%
dataset['sex'].describe()
# Out:
# count     289955
# unique         2
# top            m
# freq      211823
# Name: sex, dtype: object

# %% [markdown]
# Respecto al género, esta columna no nos aporta un valor diferencial. Simplemente nos indica si el usuario es mujer u hombre.

# %%
dataset['country'].describe()
# Out:
# count            289955
# unique              159
# top       United States
# freq              59558
# Name: country, dtype: object

# %% [markdown]
# Respecto al país puede jugar un valor algo más diferencial que el sexo en nuestro dataset pero consideramos que tampoco aporta un valor excesivamente diferencial puesto que nos vamos a centrar en los artistas

# %% [markdown]
# ### Limpieza de datos

# %%
#Valores desconocidos
dataset.loc[dataset['artist'] == '[unknown]']
dataset = dataset.replace('[unknown]',np.NaN)

# %%
#Eliminación de nulos
dataset = dataset.dropna()
print('Tamaño sin nulos',dataset.shape)

#Eliminación de duplicados
dataset = dataset.drop_duplicates()
print('Tamaño sin duplicados',dataset.shape)
dataset
# Out:
# Tamaño sin nulos (289402, 4)
# Tamaño sin duplicados (289400, 4)
#          user                   artist sex  country
# 0           1    red hot chili peppers   f  Germany
# 1           1  the black dahlia murder   f  Germany
# 2           1                goldfrapp   f  Germany
# 3           1         dropkick murphys   f  Germany
# 4           1                 le tigre   f  Germany
# ...       ...                      ...  ..      ...
# 289950  19718                bob dylan   f   Canada
# 289951  19718                   pixies   f   Canada
# 289952  19718                the clash   f   Canada
# 289953  19718     a tribe called quest   f   Canada
# 289954  19718                radiohead   f   Canada
#
# [289400 rows x 4 columns]

# %% [markdown]
# Tenemos que hacer un nuevo dataset para analizar estos datos con el algoritmo Apriori, para ello vamos a construir un dataset con un listado de ususarios con todos los artistas que ha escuchado...

# %%
dagrupado = dataset.groupby(['user','sex','country'])['artist'].agg(lambda x: list(x))
dfAgrupado = pd.DataFrame(dataset.groupby(['user','sex','country'],as_index=False)['artist'].agg(lambda x: list(x)))
dfAgrupado
# Out:
#         user sex         country  \
# 0          1   f         Germany
# 1          3   m   United States
# 2          4   m  United Kingdom
# 3          5   m         Finland
# 4          6   m        Portugal
# ...      ...  ..             ...
# 14990  19713   m         Ukraine
# 14991  19714   m  United Kingdom
# 14992  19715   m  United Kingdom
# 14993  19717   m          Brazil
# 14994  19718   f          Canada
#
#                                                   artist
# 0      [red hot chili peppers, the black dahlia murde...
# 1      [devendra banhart, boards of canada, cocorosie...
# 2      [tv on the radio, tool, kyuss, dj shadow, air,...
# 3      [dream theater, ac/dc, metallica, iron maiden,...
# 4      [lily allen, kanye west, sigur rós, pink floyd...
# ...                                                  ...
# 14990  [armin van buuren, above & beyond, atb, ferry ...
# 14991  [misfits, type o negative, arch enemy, red hot...
# 14992  [abba, james blunt, jason mraz, amy winehouse,...
# 14993  [marilyn manson, beyoncé, madonna, t.a.t.u., k...
# 14994  [beirut, of montreal, black flag, the new porn...
#
# [14995 rows x 4 columns]

# %% [markdown]
# Pese a tener los datos del país del usuario además de su género, nos damos cuenta de que estos datos carecen de valor y no aportan nada al objetivo que perseguimos, que no es más que la adquisición de los conjuntos de grupos de música más frecuentes para la obtención de reglas de asociación que nos permita el estudio de estos grupos y sus similitudes por el cual se produzcan estos agrupamientos.

# %% [markdown]
# ## 1.2 (4 puntos) Aprende a manejar la librería mlextend y su implementación del algoritmo Apriori.

# %%
te = TransactionEncoder()
te_ary = te.fit(dagrupado).transform(dagrupado)
df = pd.DataFrame(te_ary, columns=te.columns_)
df
# Out:
#        ...and you will know us by the trail of dead   2pac  3 doors down  \
# 0                                             False  False         False
# 1                                             False  False         False
# 2                                             False  False         False
# 3                                             False  False         False
# 4                                             False  False         False
# ...                                             ...    ...           ...
# 14990                                         False  False         False
# 14991                                         False  False         False
# 14992                                         False  False         False
# 14993                                         False  False         False
# 14994                                         False  False         False
#
#        30 seconds to mars    311  36 crazyfists     44  50 cent  \
# 0                   False  False          False  False    False
# 1                   False  False          False  False    False
# 2                   False  False          False  False    False
# 3                   False  False          False  False    False
# 4                   False  False          False  False    False
# ...                   ...    ...            ...    ...      ...
# 14990               False  False          False  False    False
# 14991               False  False          False  False    False
# 14992               False  False          False  False    False
# 14993               False  False          False  False    False
# 14994               False  False          False  False    False
#
#        65daysofstatic  a day to remember  ...  wilco  within temptation  \
# 0               False              False  ...  False              False
# 1               False              False  ...  False              False
# 2               False              False  ...  False              False
# 3               False              False  ...  False              False
# 4               False              False  ...  False              False
# ...               ...                ...  ...    ...                ...
# 14990           False              False  ...  False              False
# 14991           False              False  ...  False              False
# 14992           False              False  ...  False              False
# 14993           False              False  ...  False              False
# 14994           False              False  ...  False              False
#
#        wolfgang amadeus mozart  wu-tang clan  yann tiersen  yeah yeah yeahs  \
# 0                        False         False         False            False
# 1                        False         False         False            False
# 2                        False         False         False            False
# 3                        False         False         False            False
# 4                        False         False         False            False
# ...                        ...           ...           ...              ...
# 14990                    False         False         False            False
# 14991                    False         False         False            False
# 14992                     True         False         False            False
# 14993                    False         False         False            False
# 14994                    False         False         False             True
#
#        yellowcard  yo la tengo  zero 7  Édith piaf
# 0           False        False   False       False
# 1           False        False   False       False
# 2           False        False   False       False
# 3           False        False   False       False
# 4           False        False   False       False
# ...           ...          ...     ...         ...
# 14990       False        False   False       False
# 14991       False        False   False       False
# 14992       False        False   False       False
# 14993       False        False   False       False
# 14994       False        False   False       False
#
# [14995 rows x 1003 columns]

# %% [markdown]
# #### 1.2.1 Obtén los itemsets frecuentes para k=1. Para esto es necesario obtener el soporte de los itemset. Crea una función que utilice métodos de la librería mlextend de manera que dado un itemset devuelva su soporte.

# %%
#Necesitamos definir un soporte minimo. sabemos que tenemos 14995 instancias, por lo que consideramos que todo lo que este
#por encima de... 250/14995 será para nosotros válido a la hora de operar con ello
frequent_itemsets = apriori(df, min_support=0.010, use_colnames=True)
frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))
frequent_itemsets1 = frequent_itemsets[frequent_itemsets['length'] == 1]

# %%
frequent_itemsets1.reset_index()
# Out:
#      index   support              itemsets  length
# 0        0  0.022741                (2pac)       1
# 1        1  0.030944        (3 doors down)       1
# 2        2  0.032811  (30 seconds to mars)       1
# 3        3  0.021807             (50 cent)       1
# 4        4  0.013671      (65daysofstatic)       1
# ..     ...       ...                   ...     ...
# 649    649  0.012271               (wilco)       1
# 650    650  0.011937   (within temptation)       1
# 651    651  0.019607        (yann tiersen)       1
# 652    652  0.017339     (yeah yeah yeahs)       1
# 653    653  0.011270              (zero 7)       1
#
# [654 rows x 4 columns]

# %%
artistas = [];
def soporteItemset(itemset):
    #Obtengo una lista de artistas
    for x in frequent_itemsets1['itemsets']:
        artista = (list(x))
        artistas.append(artista)
    #Recorro la lista de artistas
    for i in range(len(artistas)):
        if itemset in artistas[i]:
            soporte = frequent_itemsets1.loc[i]['support']
            return 'El sporte para ' + str(itemset) + ' es de: ' + str(round(soporte,4))
    return 'El artista ' + str(itemset) + ' no está en el itemset'

# %%
coldplay = soporteItemset('coldplay')
print(coldplay)

ecdl = soporteItemset('el canto del loco')
print(ecdl)

beatles = soporteItemset('the beatles')
print(beatles)
# Out:
# El sporte para coldplay es de: 0.1586
# El artista el canto del loco no está en el itemset
# El sporte para the beatles es de: 0.1779

# %% [markdown]
# #### 1.2.2. Crea una función que devuelva los itemsets frecuentes candidatos y su soporte para k>=2

# %% [markdown]
# Creamos una función que nos irá calculando itemsets frecuentes candidatos a medida que sea posible para k>=2 y que parará cuando no se generen estos itemsets. Esta función nos sirve además para el siguiente apartado donde se pide más o menos lo mismo

# %%
def soporteItemsetKMayorIgual(k):
    #Creamos un diccionario. Esto servira para concatenarlo al nombre del itemset generado
    valoresValidosK = []
    data = dict();
    numCreados = 0;
    if k < 2:
        return 'La k debe ser mayor o igual a 2'
    else:
        while k != -1:
            print('Creando para k = ',k)
            frq = frequent_itemsets[frequent_itemsets['length'] == k]
            if(frq.shape[0] > 0):
                print(frq.shape[0])
                valoresValidosK.append(k);
                var = 'frq'+str(k);
                print(var,'Creado')
                print('Aumentamos k\n')
                k += 1;
                numCreados += 1;
            else:
                print('No se puede generar un itemset para k = ',k)
                print('Paramos el bucle. No generamos nada para k >= ',k)
                k = -1;
        for i in range(numCreados):
            data['frq'+str(valoresValidosK[i])] = frequent_itemsets[frequent_itemsets['length'] == valoresValidosK[i]]        
        print('\nPara obtener los itemsets creados consulte el diccionario que devuelve la funcion.')
        print('Se han generado',numCreados,'datasets')
        return data,numCreados

# %%
itemsets, itemSetsGenerados = soporteItemsetKMayorIgual(2)
# Out:
# Creando para k =  2
# 962
# frq2 Creado
# Aumentamos k
#
# Creando para k =  3
# 72
# frq3 Creado
# Aumentamos k
#
# Creando para k =  4
# No se puede generar un itemset para k =  4
# Paramos el bucle. No generamos nada para k >=  4
#
# Para obtener los itemsets creados consulte el diccionario que devuelve la funcion.
# Se han generado 2 datasets

# %% [markdown]
# #### 1.2.3. Crea una función que repita el paso 1.2.2. hasta que no se generen nuevos itemsets frecuentes

# %% [markdown]
# La función que hemos generado en el paso 1.2.2 ya nos hace automáticamente esta función. Es decir, hemos creado una función que nos genera automáticamente los itemsets para k>=2 y que para cuando no hay itemsets frecuentes, por tanto no es necesario volver a repetir esta función

# %%
k2 = pd.DataFrame.from_dict(itemsets['frq2'])
k2
# Out:
#        support                                    itemsets  length
# 654   0.011070                 (linkin park, 3 doors down)       2
# 655   0.012538           (linkin park, 30 seconds to mars)       2
# 656   0.011337                    (a perfect circle, muse)       2
# 657   0.010337         (a perfect circle, nine inch nails)       2
# 658   0.013471               (radiohead, a perfect circle)       2
# ...        ...                                         ...     ...
# 1611  0.011204     (the white stripes, the rolling stones)       2
# 1612  0.012738               (the rolling stones, the who)       2
# 1613  0.012538                    (u2, the rolling stones)       2
# 1614  0.010137  (the smashing pumpkins, the white stripes)       2
# 1615  0.013138            (the white stripes, the strokes)       2
#
# [962 rows x 3 columns]

# %%
k3 = pd.DataFrame.from_dict(itemsets['frq3'])
k3
# Out:
#        support                                         itemsets  length
# 1616  0.011604                 (arctic monkeys, coldplay, muse)       3
# 1617  0.013071            (radiohead, coldplay, arctic monkeys)       3
# 1618  0.012337          (coldplay, the killers, arctic monkeys)       3
# 1619  0.011004                (radiohead, arctic monkeys, muse)       3
# 1620  0.011070              (arctic monkeys, the killers, muse)       3
# ...        ...                                              ...     ...
# 1683  0.010604     (radiohead, the beatles, the rolling stones)       3
# 1684  0.010670              (radiohead, the beatles, the shins)       3
# 1685  0.011470  (radiohead, the smashing pumpkins, the beatles)       3
# 1686  0.010470            (radiohead, the beatles, the strokes)       3
# 1687  0.012271      (radiohead, the white stripes, the beatles)       3
#
# [72 rows x 3 columns]

# %% [markdown]
# #### 1.2.4. Crea una función que muestre todas las reglas posibles con su confianza

# %%
def sacarReglas(itemsets):
    reglas = association_rules(itemsets, support_only=False, metric="confidence", min_threshold=0.015)
    reglas = reglas[['antecedents', 'consequents', 'antecedent support', 'consequent support', 'support', 'lift', 'confidence']]
    return reglas
sacarReglas(frequent_itemsets)
# Out:
#                            antecedents                       consequents  \
# 0                        (linkin park)                    (3 doors down)
# 1                       (3 doors down)                     (linkin park)
# 2                        (linkin park)              (30 seconds to mars)
# 3                 (30 seconds to mars)                     (linkin park)
# 4                   (a perfect circle)                            (muse)
# ...                                ...                               ...
# 2351          (radiohead, the beatles)               (the white stripes)
# 2352  (the white stripes, the beatles)                       (radiohead)
# 2353                       (radiohead)  (the white stripes, the beatles)
# 2354               (the white stripes)          (radiohead, the beatles)
# 2355                     (the beatles)    (radiohead, the white stripes)
#
#       antecedent support  consequent support   support      lift  confidence
# 0               0.098233            0.030944  0.011070  3.641949    0.112695
# 1               0.030944            0.098233  0.011070  3.641949    0.357759
# 2               0.098233            0.032811  0.012538  3.889882    0.127631
# 3               0.032811            0.098233  0.012538  3.889882    0.382114
# 4               0.036746            0.114105  0.011337  2.703920    0.308530
# ...                  ...                 ...       ...       ...         ...
# 2351            0.058219            0.069223  0.012271  3.044757    0.210767
# 2352            0.025475            0.180327  0.012271  2.671125    0.481675
# 2353            0.180327            0.025475  0.012271  2.671125    0.068047
# 2354            0.069223            0.058219  0.012271  3.044757    0.177264
# 2355            0.177926            0.027276  0.012271  2.528455    0.068966
#
# [2356 rows x 7 columns]

# %% [markdown]
# #### 1.2.5. Lista todas las reglas que sean de alta confianza (p.ej. con valor >=0.5)

# %%
reglasAltaConfi = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.5)
reglasAltaConfi = reglasAltaConfi[['antecedents', 'consequents', 'confidence', 'lift']]

# %%
reglasAltaConfi
# Out:
#                              antecedents     consequents  confidence  \
# 0                                 (beck)     (radiohead)    0.509281
# 1                                 (blur)     (radiohead)    0.522863
# 2                  (broken social scene)     (radiohead)    0.547215
# 3                                (keane)      (coldplay)    0.637405
# 4                          (snow patrol)      (coldplay)    0.525132
# 5                             (the fray)      (coldplay)    0.516820
# 6                               (travis)      (coldplay)    0.562842
# 7                         (judas priest)   (iron maiden)    0.507500
# 8                                 (t.i.)    (kanye west)    0.567273
# 9                             (megadeth)     (metallica)    0.528139
# 10                      (sonata arctica)     (nightwish)    0.510101
# 11                    (the flaming lips)     (radiohead)    0.529730
# 12                  (the pussycat dolls)       (rihanna)    0.577778
# 13                   (simon & garfunkel)   (the beatles)    0.523810
# 14                           (the kinks)   (the beatles)    0.529870
# 15                   (beck, the beatles)     (radiohead)    0.590909
# 16             (the killers, bloc party)      (coldplay)    0.523659
# 17               (bob dylan, pink floyd)   (the beatles)    0.615079
# 18                (radiohead, bob dylan)   (the beatles)    0.573003
# 19       (bob dylan, the rolling stones)   (the beatles)    0.591065
# 20    (death cab for cutie, the killers)      (coldplay)    0.588448
# 21                   (the killers, muse)      (coldplay)    0.508969
# 22                    (radiohead, oasis)      (coldplay)    0.587692
# 23                  (oasis, the beatles)      (coldplay)    0.519608
# 24                  (oasis, the killers)      (coldplay)    0.662698
# 25                 (coldplay, sigur rós)     (radiohead)    0.580128
# 26              (radiohead, snow patrol)      (coldplay)    0.634454
# 27              (radiohead, the killers)      (coldplay)    0.524362
# 28     (the smashing pumpkins, coldplay)     (radiohead)    0.628352
# 29                       (u2, radiohead)      (coldplay)    0.521341
# 30  (red hot chili peppers, the killers)      (coldplay)    0.509375
# 31            (the killers, snow patrol)      (coldplay)    0.595420
# 32            (the beatles, the killers)      (coldplay)    0.534091
# 33             (pink floyd, david bowie)   (the beatles)    0.574144
# 34              (radiohead, david bowie)   (the beatles)    0.522500
# 35     (david bowie, the rolling stones)   (the beatles)    0.570342
# 36    (the beatles, death cab for cutie)     (radiohead)    0.501340
# 37      (death cab for cutie, the shins)     (radiohead)    0.503333
# 38               (the doors, pink floyd)  (led zeppelin)    0.538721
# 39             (the doors, led zeppelin)    (pink floyd)    0.597015
# 40             (radiohead, led zeppelin)   (the beatles)    0.528302
# 41    (led zeppelin, the rolling stones)   (the beatles)    0.577617
# 42                  (radiohead, placebo)          (muse)    0.513784
# 43                   (the beatles, muse)     (radiohead)    0.507353
# 44               (the doors, pink floyd)   (the beatles)    0.505051
# 45              (the beatles, sigur rós)     (radiohead)    0.643443
# 46       (radiohead, the rolling stones)   (the beatles)    0.563830
# 47              (the beatles, the shins)     (radiohead)    0.567376
# 48  (the smashing pumpkins, the beatles)     (radiohead)    0.620939
# 49            (the beatles, the strokes)     (radiohead)    0.560714
#
#          lift
# 0    2.824210
# 1    2.899530
# 2    3.034577
# 3    4.019294
# 4    3.311337
# 5    3.258919
# 6    3.549121
# 7    8.560138
# 8    8.851462
# 9    4.742178
# 10   8.233546
# 11   2.937610
# 12  13.411421
# 13   2.943974
# 14   2.978037
# 15   3.276879
# 16   3.302048
# 17   3.456940
# 18   3.220456
# 19   3.321973
# 20   3.710586
# 21   3.209413
# 22   3.705823
# 23   3.276501
# 24   4.178790
# 25   3.217094
# 26   4.000687
# 27   3.306479
# 28   3.484521
# 29   3.287433
# 30   3.211976
# 31   3.754550
# 32   3.367827
# 33   3.226873
# 34   2.936615
# 35   3.205503
# 36   2.780178
# 37   2.791229
# 38   6.799760
# 39   5.687572
# 40   2.969223
# 41   3.246391
# 42   4.502746
# 43   2.813520
# 44   2.838543
# 45   3.568203
# 46   3.168901
# 47   3.146376
# 48   3.443408
# 49   3.109434

# %% [markdown]
# #### 1.2.6. Crea funciones que permitan lo siguiente:
# <ul>
#     <li><b>* devolver todas las reglas que contengan un antecesor dado</b></li>
#     <li><b>* devolver todas las reglas que tengan una confianza mayor (o igual) que un umbral mínimo dado</b></li>
#     <li><b>* devolver todas las reglas que tengan un lift en una de las tres franjas de estudio (under 1, over 1, =1)</b></li>
# </ul>

# %%
def reglasAntecesor(antecesor):
    antecedents = reglasAltaConfi['antecedents']
    index = antecedents.where([bool(antecesor in a) for a in list(antecedents)]).dropna().index
    return reglasAltaConfi.loc[index, :]

# %% [markdown]
# #### Reglas con un antecesor dado por parámetro

# %%
reglasAntecesor('the killers')
# Out:
#                              antecedents consequents  confidence      lift
# 16             (the killers, bloc party)  (coldplay)    0.523659  3.302048
# 20    (death cab for cutie, the killers)  (coldplay)    0.588448  3.710586
# 21                   (the killers, muse)  (coldplay)    0.508969  3.209413
# 24                  (oasis, the killers)  (coldplay)    0.662698  4.178790
# 27              (radiohead, the killers)  (coldplay)    0.524362  3.306479
# 30  (red hot chili peppers, the killers)  (coldplay)    0.509375  3.211976
# 31            (the killers, snow patrol)  (coldplay)    0.595420  3.754550
# 32            (the beatles, the killers)  (coldplay)    0.534091  3.367827

# %%
def reglasConfianza(confianza):
    confidence = reglasAltaConfi['confidence']
    index = confidence.where(confidence >= confianza).dropna().index
    return reglasAltaConfi.loc[index, :]

# %% [markdown]
# #### Reglas con la confianza mayor o igual que un valor dado

# %%
reglasConfianza(0.6)
# Out:
#                              antecedents    consequents  confidence      lift
# 3                                (keane)     (coldplay)    0.637405  4.019294
# 17               (bob dylan, pink floyd)  (the beatles)    0.615079  3.456940
# 24                  (oasis, the killers)     (coldplay)    0.662698  4.178790
# 26              (radiohead, snow patrol)     (coldplay)    0.634454  4.000687
# 28     (the smashing pumpkins, coldplay)    (radiohead)    0.628352  3.484521
# 45              (the beatles, sigur rós)    (radiohead)    0.643443  3.568203
# 48  (the smashing pumpkins, the beatles)    (radiohead)    0.620939  3.443408

# %%
def reglasLift(lft):
    lift = reglasAltaConfi['lift']
    if lft == 1: 
        index = lift.where(lift == lft).dropna().index
    elif lft > 1:
        index = lift.where(lift > lft).dropna().index
    elif lft < 1:
        index = lift.where(lift < lft).dropna().index
    
    return reglasAltaConfi.loc[index, :]

# %% [markdown]
# #### Reglas con Lift dado

# %%
reglasLift(0.9)
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, confidence, lift]
# Index: []

# %%
reglasLift(1)
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, confidence, lift]
# Index: []

# %%
reglasLift(1.1)
# Out:
#                              antecedents     consequents  confidence  \
# 0                                 (beck)     (radiohead)    0.509281
# 1                                 (blur)     (radiohead)    0.522863
# 2                  (broken social scene)     (radiohead)    0.547215
# 3                                (keane)      (coldplay)    0.637405
# 4                          (snow patrol)      (coldplay)    0.525132
# 5                             (the fray)      (coldplay)    0.516820
# 6                               (travis)      (coldplay)    0.562842
# 7                         (judas priest)   (iron maiden)    0.507500
# 8                                 (t.i.)    (kanye west)    0.567273
# 9                             (megadeth)     (metallica)    0.528139
# 10                      (sonata arctica)     (nightwish)    0.510101
# 11                    (the flaming lips)     (radiohead)    0.529730
# 12                  (the pussycat dolls)       (rihanna)    0.577778
# 13                   (simon & garfunkel)   (the beatles)    0.523810
# 14                           (the kinks)   (the beatles)    0.529870
# 15                   (beck, the beatles)     (radiohead)    0.590909
# 16             (the killers, bloc party)      (coldplay)    0.523659
# 17               (bob dylan, pink floyd)   (the beatles)    0.615079
# 18                (radiohead, bob dylan)   (the beatles)    0.573003
# 19       (bob dylan, the rolling stones)   (the beatles)    0.591065
# 20    (death cab for cutie, the killers)      (coldplay)    0.588448
# 21                   (the killers, muse)      (coldplay)    0.508969
# 22                    (radiohead, oasis)      (coldplay)    0.587692
# 23                  (oasis, the beatles)      (coldplay)    0.519608
# 24                  (oasis, the killers)      (coldplay)    0.662698
# 25                 (coldplay, sigur rós)     (radiohead)    0.580128
# 26              (radiohead, snow patrol)      (coldplay)    0.634454
# 27              (radiohead, the killers)      (coldplay)    0.524362
# 28     (the smashing pumpkins, coldplay)     (radiohead)    0.628352
# 29                       (u2, radiohead)      (coldplay)    0.521341
# 30  (red hot chili peppers, the killers)      (coldplay)    0.509375
# 31            (the killers, snow patrol)      (coldplay)    0.595420
# 32            (the beatles, the killers)      (coldplay)    0.534091
# 33             (pink floyd, david bowie)   (the beatles)    0.574144
# 34              (radiohead, david bowie)   (the beatles)    0.522500
# 35     (david bowie, the rolling stones)   (the beatles)    0.570342
# 36    (the beatles, death cab for cutie)     (radiohead)    0.501340
# 37      (death cab for cutie, the shins)     (radiohead)    0.503333
# 38               (the doors, pink floyd)  (led zeppelin)    0.538721
# 39             (the doors, led zeppelin)    (pink floyd)    0.597015
# 40             (radiohead, led zeppelin)   (the beatles)    0.528302
# 41    (led zeppelin, the rolling stones)   (the beatles)    0.577617
# 42                  (radiohead, placebo)          (muse)    0.513784
# 43                   (the beatles, muse)     (radiohead)    0.507353
# 44               (the doors, pink floyd)   (the beatles)    0.505051
# 45              (the beatles, sigur rós)     (radiohead)    0.643443
# 46       (radiohead, the rolling stones)   (the beatles)    0.563830
# 47              (the beatles, the shins)     (radiohead)    0.567376
# 48  (the smashing pumpkins, the beatles)     (radiohead)    0.620939
# 49            (the beatles, the strokes)     (radiohead)    0.560714
#
#          lift
# 0    2.824210
# 1    2.899530
# 2    3.034577
# 3    4.019294
# 4    3.311337
# 5    3.258919
# 6    3.549121
# 7    8.560138
# 8    8.851462
# 9    4.742178
# 10   8.233546
# 11   2.937610
# 12  13.411421
# 13   2.943974
# 14   2.978037
# 15   3.276879
# 16   3.302048
# 17   3.456940
# 18   3.220456
# 19   3.321973
# 20   3.710586
# 21   3.209413
# 22   3.705823
# 23   3.276501
# 24   4.178790
# 25   3.217094
# 26   4.000687
# 27   3.306479
# 28   3.484521
# 29   3.287433
# 30   3.211976
# 31   3.754550
# 32   3.367827
# 33   3.226873
# 34   2.936615
# 35   3.205503
# 36   2.780178
# 37   2.791229
# 38   6.799760
# 39   5.687572
# 40   2.969223
# 41   3.246391
# 42   4.502746
# 43   2.813520
# 44   2.838543
# 45   3.568203
# 46   3.168901
# 47   3.146376
# 48   3.443408
# 49   3.109434

# %% [markdown]
# #### 1.2.7. Utiliza al menos dos representaciones gráficas para mostrar las reglas obtenidas e interpretar los datos

# %% [markdown]
# Al no especificar qué reglas debemos mostrar nos hemos decantado por sacar, de las reglas generales la relación de la confianza con el soporte y ver cómo están relacionadas entre ellas

# %%
reglasGenerales = sacarReglas(frequent_itemsets)
reglasGenerales
# Out:
#                            antecedents                       consequents  \
# 0                        (linkin park)                    (3 doors down)
# 1                       (3 doors down)                     (linkin park)
# 2                        (linkin park)              (30 seconds to mars)
# 3                 (30 seconds to mars)                     (linkin park)
# 4                   (a perfect circle)                            (muse)
# ...                                ...                               ...
# 2351          (radiohead, the beatles)               (the white stripes)
# 2352  (the white stripes, the beatles)                       (radiohead)
# 2353                       (radiohead)  (the white stripes, the beatles)
# 2354               (the white stripes)          (radiohead, the beatles)
# 2355                     (the beatles)    (radiohead, the white stripes)
#
#       antecedent support  consequent support   support      lift  confidence
# 0               0.098233            0.030944  0.011070  3.641949    0.112695
# 1               0.030944            0.098233  0.011070  3.641949    0.357759
# 2               0.098233            0.032811  0.012538  3.889882    0.127631
# 3               0.032811            0.098233  0.012538  3.889882    0.382114
# 4               0.036746            0.114105  0.011337  2.703920    0.308530
# ...                  ...                 ...       ...       ...         ...
# 2351            0.058219            0.069223  0.012271  3.044757    0.210767
# 2352            0.025475            0.180327  0.012271  2.671125    0.481675
# 2353            0.180327            0.025475  0.012271  2.671125    0.068047
# 2354            0.069223            0.058219  0.012271  3.044757    0.177264
# 2355            0.177926            0.027276  0.012271  2.528455    0.068966
#
# [2356 rows x 7 columns]

# %%
soporte = reglasGenerales['support'].values
confianza = reglasGenerales['confidence'].values

# %% [markdown]
# Obtenemos todas las reglas fenerales. Ahora pondremos la relación entre soporte y confianza en una gráfica

# %%
import random
import matplotlib.pyplot as plt
 
for i in range (len(soporte)):
    soporte[i] = soporte[i] + 0.0025 * (random.randint(1,10) - 5) 
    confianza[i] = confianza[i] + 0.0025 * (random.randint(1,10) - 5)

fig = plt.figure(figsize = (10,8), dpi=360)
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Confianza', fontsize = 10)
ax.set_ylabel('Soporte', fontsize = 10)
ax.set_title('Relación Soporte - Confianza Reglas Asociación', fontsize = 14)
ax.scatter(soporte, confianza, alpha=0.3, marker="+")
plt.show()

# %% [markdown]
# Por último, como tenemos las reglas generales, buscamos en las reglas generales aquellas que tengan como consecuente un grupo, en nuestro caso vamos a elegir el grupo Queen y veremos como se relacionan antecedentes y consecuentes, es decir, una relación de cómo interactúan los usarios que escuchan Queen. Cuando escuchan a qué artistas, luego escuchan a Queen.

# %%
reglasACDCCons = reglasGenerales.loc[reglasGenerales['consequents'].isin(['ac/dc'])]
reglasACDCCons
# Out:
# Empty DataFrame
# Columns: [antecedents, consequents, antecedent support, consequent support, support, lift, confidence]
# Index: []

# %%
queen = reglasGenerales[reglasGenerales['consequents'].astype(str).str.lower().str.contains('queen')]
queen.reset_index()
# Out:
#     index                antecedents                consequents  \
# 0      26                    (ac/dc)                    (queen)
# 1     529                 (coldplay)                    (queen)
# 2     633              (david bowie)                    (queen)
# 3     848             (foo fighters)                    (queen)
# 4     850             (foo fighters)  (queens of the stone age)
# 5     928                (green day)                    (queen)
# 6    1013              (iron maiden)                    (queen)
# 7    1163             (led zeppelin)                    (queen)
# 8    1164             (led zeppelin)  (queens of the stone age)
# 9    1296                (metallica)                    (queen)
# 10   1336          (michael jackson)                    (queen)
# 11   1397                     (muse)                    (queen)
# 12   1399                     (muse)  (queens of the stone age)
# 13   1460          (nine inch nails)  (queens of the stone age)
# 14   1486                  (nirvana)                    (queen)
# 15   1488                  (nirvana)  (queens of the stone age)
# 16   1561               (pink floyd)                    (queen)
# 17   1640                (radiohead)                    (queen)
# 18   1643    (red hot chili peppers)                    (queen)
# 19   1644         (system of a down)                    (queen)
# 20   1647              (the beatles)                    (queen)
# 21   1648                (the doors)                    (queen)
# 22   1651              (the killers)                    (queen)
# 23   1653       (the rolling stones)                    (queen)
# 24   1655                  (the who)                    (queen)
# 25   1656                       (u2)                    (queen)
# 26   1658                (radiohead)  (queens of the stone age)
# 27   1660    (red hot chili peppers)  (queens of the stone age)
# 28   1662              (the beatles)  (queens of the stone age)
# 29   1664        (the white stripes)  (queens of the stone age)
# 30   2292  (pink floyd, the beatles)                    (queen)
# 31   2294               (pink floyd)       (queen, the beatles)
# 32   2295              (the beatles)        (queen, pink floyd)
#
#     antecedent support  consequent support   support      lift  confidence
# 0             0.061420            0.077759  0.012604  2.639065    0.197712
# 1             0.158586            0.077759  0.033440  1.698110    0.132044
# 2             0.073691            0.077759  0.025371  2.246172    0.174661
# 3             0.073358            0.077759  0.000070  1.765356    0.127273
# 4             0.073358            0.049483  0.023738  3.784575    0.177273
# 5             0.070890            0.077759  0.000670  1.935685    0.163017
# 6             0.059286            0.077759  0.020337  2.242218    0.164353
# 7             0.079226            0.077759  0.013772  2.641322    0.197887
# 8             0.079226            0.049483  0.015203  2.602661    0.126288
# 9             0.111370            0.077759  0.017806  2.056093    0.164880
# 10            0.056352            0.077759  0.015270  2.343753    0.174749
# 11            0.114105            0.077759  0.023938  1.570884    0.122151
# 12            0.114105            0.049483  0.020205  2.692944    0.125755
# 13            0.066489            0.049483  0.010937  3.324231    0.174493
# 14            0.098233            0.077759  0.007804  1.676279    0.137846
# 15            0.098233            0.049483  0.022538  2.579275    0.127631
# 16            0.104968            0.077759  0.016407  2.622698    0.206439
# 17            0.180327            0.077759  0.025539  1.108146    0.078669
# 18            0.119106            0.077759  0.008905  1.771339    0.140238
# 19            0.091030            0.077759  0.017703  1.441474    0.114588
# 20            0.177926            0.077759  0.037310  2.154615    0.162541
# 21            0.057619            0.077759  0.013370  2.426173    0.186157
# 22            0.098233            0.077759  0.007204  1.597704    0.136736
# 23            0.062954            0.077759  0.003605  2.779112    0.218602
# 24            0.034812            0.077759  0.007503  3.695461    0.289856
# 25            0.068023            0.077759  0.019538  2.748554    0.206225
# 26            0.180327            0.049483  0.012973  2.294427    0.126036
# 27            0.119106            0.049483  0.004304  2.002785    0.106604
# 28            0.177926            0.049483  0.005438  1.469462    0.080214
# 29            0.069223            0.049483  0.009171  3.407087    0.171093
# 30            0.039680            0.077759  0.020403  3.371751    0.252185
# 31            0.104968            0.029810  0.012903  3.324749    0.091611
# 32            0.177926            0.021407  0.020403  2.731368    0.053471

# %%
antecedentes = []
consecuentes = []
for t in queen['antecedents']:
    texto = str(t);
    texto = texto.replace("frozenset({", "")
    texto = texto.replace("})", "")
    antecedentes.append(texto)
    

for t in queen['consequents']:
    texto = str(t);
    texto = texto.replace("frozenset({", "")
    texto = texto.replace("})", "")
    consecuentes.append(texto)

# %%
data = {'antecedentes': antecedentes, 
        'consecuentes': consecuentes} 
  
# Convert the dictionary into DataFrame 
queen = pd.DataFrame(data) 
queen
# Out:
#                    antecedentes               consecuentes
# 0                       'ac/dc'                    'queen'
# 1                    'coldplay'                    'queen'
# 2                 'david bowie'                    'queen'
# 3                'foo fighters'                    'queen'
# 4                'foo fighters'  'queens of the stone age'
# 5                   'green day'                    'queen'
# 6                 'iron maiden'                    'queen'
# 7                'led zeppelin'                    'queen'
# 8                'led zeppelin'  'queens of the stone age'
# 9                   'metallica'                    'queen'
# 10            'michael jackson'                    'queen'
# 11                       'muse'                    'queen'
# 12                       'muse'  'queens of the stone age'
# 13            'nine inch nails'  'queens of the stone age'
# 14                    'nirvana'                    'queen'
# 15                    'nirvana'  'queens of the stone age'
# 16                 'pink floyd'                    'queen'
# 17                  'radiohead'                    'queen'
# 18      'red hot chili peppers'                    'queen'
# 19           'system of a down'                    'queen'
# 20                'the beatles'                    'queen'
# 21                  'the doors'                    'queen'
# 22                'the killers'                    'queen'
# 23         'the rolling stones'                    'queen'
# 24                    'the who'                    'queen'
# 25                         'u2'                    'queen'
# 26                  'radiohead'  'queens of the stone age'
# 27      'red hot chili peppers'  'queens of the stone age'
# 28                'the beatles'  'queens of the stone age'
# 29          'the white stripes'  'queens of the stone age'
# 30  'pink floyd', 'the beatles'                    'queen'
# 31                 'pink floyd'     'queen', 'the beatles'
# 32                'the beatles'      'queen', 'pink floyd'

# %%
import networkx as nx

fig = plt.figure(figsize = (20,10), dpi=360)
ax = fig.add_subplot(1,1,1)
ax.set_title('Artistas Consecuentes de Queen', fontsize = 20)
GA=nx.from_pandas_edgelist(queen, source='antecedentes', target='consecuentes')
nx.draw(GA,with_labels=True)
plt.rcParams['font.size'] = 10
plt.show()

# %% [markdown]
# #### Podemos observar que Queen está relacionado directamente con grupos como The Killers, The Who o incluso Pink Floyd. Tiene una relación curiosa con Led Zeppelin, mediante la que descubrimos que se une a Queens of the Stone Age descubriendo aquí una nueva relación entre Queen y estos últimos mediante Led Zeppelin. Ocurre lo mismo con The Beatles y una consecuente subconexión con Pink Floyd
